# %% [markdown]
# # GitStractor Jupyter Notebook Data Visualization
#
# This notebook serves as a set of examples for visualizing codebases using [GitStractor](https://github.com/integerman/gitstractor) and Jupyter Notebooks.
#
# Contact [Matt Eland](https://MattEland.dev) with questions.

# %% [markdown]
# ## Requirements
#
# This application currently requires:
#
# - CSV files generated by [GitStractor](https://github.com/integerman/gitstractor)
# - Jupyter Notebooks running some version of Python (tested using Python 3.8.8)
# - The following Python libraries:
#   - pandas
#   - plotly.express

# %%
# Load Dependencies

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Data Loading

# %%
# This should point to the location containing the GitStractor CSV files
data_dir = 'C:\\tools\\gitstractor'

# These are the default GitStractor file names and shouldn't need to be customized
author_file = data_dir + '\\Authors.csv'
commits_file = data_dir + '\\Commits.csv'
file_commits_file = data_dir + '\\FileCommits.csv'
files_file = data_dir + '\\Files.csv'
final_structure_file = data_dir + '\\FinalStructure.csv'

# %% [markdown]
# ### Load Authors

# %%
df_authors = pd.read_csv(author_file)

df_authors.head(5)
# Out:
#               Name                                     Email  NumCommits  \
# 0       Matt Eland                      Matt.Eland@GMail.com         229
# 1  repo-visualizer  repo-visualizer@users.noreply.github.com          42
#
#    TotalBytes
# 0     5033233
# 1     2332366

# %% [markdown]
# ### Load Commits

# %%
df_commits = pd.read_csv(commits_file)

df_commits.head(5)
# Out:
#                                  CommitHash           AuthorEmail  \
# 0  0df430136e5ca0af02175d3acc40935e572528a5  Matt.Eland@GMail.com
# 1  aec4a2c1f9283bc6da50e264a3ca8743b1f05410  Matt.Eland@GMail.com
# 2  85f8e28806fa77c22764300502889d9af4a4740d  Matt.Eland@GMail.com
# 3  5b407858d926bd50620376f0d7ebf871b392e87d  Matt.Eland@GMail.com
# 4  c8886dca6f7bbb999670b9dd89dd03dd530cecac  Matt.Eland@GMail.com
#
#          AuthorDateUTC        CommitterEmail        CommitterDate  \
# 0  7/4/2022 2:56:36 AM  Matt.Eland@GMail.com  7/4/2022 2:56:36 AM
# 1  7/4/2022 3:07:48 AM  Matt.Eland@GMail.com  7/4/2022 3:07:48 AM
# 2  7/4/2022 3:52:20 AM  Matt.Eland@GMail.com  7/4/2022 3:52:20 AM
# 3  7/4/2022 4:03:53 AM  Matt.Eland@GMail.com  7/4/2022 4:03:53 AM
# 4  7/4/2022 4:32:35 AM  Matt.Eland@GMail.com  7/4/2022 4:32:35 AM
#
#                                  Message  NumFiles  AddedFiles  DeletedFiles  \
# 0                         Initial commit         3           3             0
# 1                Project structure setup        11           9             0
# 2                          Initial setup        12           9             0
# 3  Now tracking game knowledge as events         6           2             0
# 4                      Doggo night phase        11           3             0
#
#    TotalFiles  TotalBytes                                          FileNames
# 0           3        7175  dfcfd5 .gitignore @ 0df430 (Added), 144780 LIC...
# 1          12      579000  f0bb9e .gitignore @ aec4a2 (Modified), e34634 ...
# 2          20        7922  ec60a2 MattEland.WhereDoggo/MattEland.WhereDog...
# 3          22        3716  bca261 MattEland.WhereDoggo/MattEland.WhereDog...
# 4          25        8770  06c73b MattEland.WhereDoggo/MattEland.WhereDog...

# %%
df_file_commits = pd.read_csv(file_commits_file)

df_file_commits.head()
# Out:
#                                             FilePath  \
# 0                                         .gitignore
# 1                                            LICENSE
# 2                                          README.md
# 3                                         .gitignore
# 4  MattEland.WhereDoggo/MattEland.WhereDoggo.Core...
#
#                                    FileHash  \
# 0  dfcfd56f444f9ae40e1082c07fe254cc547136cf
# 1  1447802c73221ff4f9a42fe06f922d70a1c1c108
# 2  fa40df806092ac52d73705a6e53e941c1686b328
# 3  f0bb9e4ba2142c160fc712ab167ffed69820d129
# 4  e34634acd363adb59e62845b3168ff76f79a6a92
#
#                                  CommitHash           AuthorEmail  \
# 0  0df430136e5ca0af02175d3acc40935e572528a5  Matt.Eland@GMail.com
# 1  0df430136e5ca0af02175d3acc40935e572528a5  Matt.Eland@GMail.com
# 2  0df430136e5ca0af02175d3acc40935e572528a5  Matt.Eland@GMail.com
# 3  aec4a2c1f9283bc6da50e264a3ca8743b1f05410  Matt.Eland@GMail.com
# 4  aec4a2c1f9283bc6da50e264a3ca8743b1f05410  Matt.Eland@GMail.com
#
#          AuthorDateUTC        CommitterEmail        CommitterDate  \
# 0  7/4/2022 2:56:36 AM  Matt.Eland@GMail.com  7/4/2022 2:56:36 AM
# 1  7/4/2022 2:56:36 AM  Matt.Eland@GMail.com  7/4/2022 2:56:36 AM
# 2  7/4/2022 2:56:36 AM  Matt.Eland@GMail.com  7/4/2022 2:56:36 AM
# 3  7/4/2022 3:07:48 AM  Matt.Eland@GMail.com  7/4/2022 3:07:48 AM
# 4  7/4/2022 3:07:48 AM  Matt.Eland@GMail.com  7/4/2022 3:07:48 AM
#
#                    Message  Bytes  Lines
# 0           Initial commit   6002    350
# 1           Initial commit   1067     21
# 2           Initial commit    106      2
# 3  Project structure setup   6036    352
# 4  Project structure setup    628     21

# %% [markdown]
# ### Load File Structure

# %%
df_structure = pd.read_csv(final_structure_file)

df_structure.head(5)
# Out:
#                                  CommitHash  \
# 0  5646a44aa369f67be1ff7f261c4d85511aece73a
# 1  5646a44aa369f67be1ff7f261c4d85511aece73a
# 2  5646a44aa369f67be1ff7f261c4d85511aece73a
# 3  5646a44aa369f67be1ff7f261c4d85511aece73a
# 4  5646a44aa369f67be1ff7f261c4d85511aece73a
#
#                                    FileHash             Filename   Extension  \
# 0  3a02aa0a8c9f1d0b74b6ab88a28388261064ba49            build.yml        .yml
# 1  76c64c7d8236de7fb1edff9967f5d4afe2618e45  codeql-analysis.yml        .yml
# 2  c9112b4f26f5ef36b38a2364bdd21edd6098b9f3   create-diagram.yml        .yml
# 3  1d9b645bbe2bf4c1ae117911534431038bb23a49           .gitignore  .gitignore
# 4  568164e0c18ed80f5fffc7296d258f67e242951a          AIDesign.md         .md
#
#                                 FilePath  State  Lines  Bytes  \
# 0            .github/workflows/build.yml  Final     49   1965
# 1  .github/workflows/codeql-analysis.yml  Final     72   2727
# 2   .github/workflows/create-diagram.yml  Final     16    343
# 3                             .gitignore  Final    356   6125
# 4                            AIDesign.md  Final     39    953
#
#          CreatedDateUTC    Path1      Path2 Path3 Path4  Path5
# 0  12/1/2022 7:28:40 PM  .github  workflows   NaN   NaN    NaN
# 1  12/1/2022 7:28:40 PM  .github  workflows   NaN   NaN    NaN
# 2  12/1/2022 7:28:40 PM  .github  workflows   NaN   NaN    NaN
# 3  12/1/2022 7:28:40 PM      NaN        NaN   NaN   NaN    NaN
# 4  12/1/2022 7:28:40 PM      NaN        NaN   NaN   NaN    NaN

# %% [markdown]
# ## Data Visualization

# %%
import plotly.express as px
import plotly.graph_objects as go
